# %%
first_name='ayush'
sirname=first_name+' '+'siloiya'

# %%
sirname
# Out:
# 'ayush siloiya'

# %%
sirname=first_name.upper()

# %%
sirname
# Out:
# 'AYUSH'

# %%
first_name=first_name.replace('ay','di').upper()
first_name
# Out:
# 'DIUSH'

# %%
n1=(1,4,3,7,2)
n2=sorted(n1)
n2
# Out:
# [1, 2, 3, 4, 7]

# %%
l1=[1,2,3,4,'ayush']
l2=l1+['ayush siloiya',5,6,7,8,9,10]
l2
# Out:
# [1, 2, 3, 4, 'ayush', 'ayush siloiya', 5, 6, 7, 8, 9, 10]

# %%
l1=[1,'ayushsiloiya',4,5,6]
"ayushsiloiya".split()
# Out:
# ['ayushsiloiya']

# %%
'ayushsiloiya'.split()
# Out:
# ['ayushsiloiya']

# %%
[1,2,3]+[1,1,1]
# Out:
# [1, 2, 3, 1, 1, 1]

# %%
dict={'ayush':'firstname','siloiya':'sirname'}
dict
# Out:
# {'ayush': 'firstname', 'siloiya': 'sirname'}

# %%
dict={'ayush':'firstname','siloiya':'sirname'}

# %%
set={1,2,3,4,5,'a','b','c','d','e'}
set.add('f')
set.remove('a')
set
# Out:
# {1, 2, 3, 4, 5, 'b', 'c', 'd', 'e', 'f'}

# %%
set1={1,2,3}
set1
# Out:
# {1, 2, 3}

# %%
set1={1,2,3,4}  ##finding the union 
set2={2,4,5,7}
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
set1&set2 ##finding the intersection
# Out:
# {2, 4}

# %%
set1.issubset(set2) ##issubset  or issuperst or uniom or difference
# Out:
# False

# %%
1 in set1
# Out:
# True

# %%
'a'=='A'
# Out:
# False

# %%
True or False
# Out:
# True

# %%
l1=[23,45,67,43,54,65,76]
l2=sum(l1)

# %%
l2
# Out:
# 373

# %%
 def add(a):
    b=a+1
    return b
add(4)
# Out:
# 5

# %%
def add(a):
    b=a+1
    c=b+2
    return(c)
def sub(d):
    e=d-2
    f=e+2
    return(f)
add(4)
# Out:
# 7

# %%
def mul(a):
    c=a/2
    d=c+1
    return(d)
mul(4)
# Out:
# 3.0

# %%
def test(x):
    a=x+2
    d=a+5
    c=d+8
    return(c)
test(4)
# Out:
# 19

# %%
def mul(a,b):
    c=a*b
    return(c)
mul(2,'ayush siloiya')
# Out:
# 'ayush siloiyaayush siloiya'

# %%
def mul(a,b):
    c=a*b
    return(c)
mul(2,3)
# Out:
# 6

# %%
##sorted returns a new list but not change the list.
##where as sort returns the same list with arrange.
l1=[46,45,5]
l1.sort()
l1
# Out:
# [5, 45, 46]

# %%
file=open('Book1.csv','w')  ##file by python
file.mode
# Out:
# 'w'

# %%
file.close()

# %%
file.name
# Out:
# 'Book1.csv'

# %%
with open('Book1.csv','r') as file:  ##method 2 for accesssing file contents
    file1=file.readline()
    print(file1)
print(file.closed)
print(file1)
# Out:
# True

# %%
with open("‪‪Book1.csv","w") as write: ##actual not error but file directory as missing .
    file.write("Hi myself ayush hacked your database")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AYUSHS~1\AppData\Local\Temp/ipykernel_8740/264440601.py in <module>
#       1 with open("‪‪Book1.csv","w") as write:
# ----> 2     file.write("Hi myself ayush hacked your database")
#
# NameError: name 'file' is not defined

# %%
import numpy as np  ##graph plot by python.
x=np.linspace(3,2*np.pi,10)
y=np.cos(x)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y)

# %%
##extras for plotting the graph  
x=np.linspace(0,2*np.pi,num=6)
y=np.sin(x)
plt.plot(x,y)

# %%
##sample1
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x=np.linspace(2,5*np.pi,num=2)
y=np.sin(x)
plt.plot(x,y)

# %%
u=np.array([0,2])  ##finding the dot product in numpy.
v=np.array([2,7])
np.dot(u,v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AYUSHS~1\AppData\Local\Temp/ipykernel_20040/519359600.py in <module>
# ----> 1 u=np.array([0,2])  ##finding the dot product in numpy.
#       2 v=np.array([2,7])
#       3 np.dot(u,v)
#
# NameError: name 'np' is not defined

# %%
np.mean(u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AYUSHS~1\AppData\Local\Temp/ipykernel_20040/3404135234.py in <module>
# ----> 1 np.mean(u)
#
# NameError: name 'np' is not defined

# %%
np.mean(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AYUSHS~1\AppData\Local\Temp/ipykernel_20040/143400375.py in <module>
# ----> 1 np.mean(v)
#
# NameError: name 'np' is not defined

# %%
np.max(u)
# Out:
# 2

# %%
a=[[1,2,3],[5,6,7],[8,9,10]]
A=np.array(a)

# %%
A
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6,  7],
#        [ 8,  9, 10]])

# %%
A.size ##  3*3=9 so the size is 9.
# Out:
# 9

# %%
x=np.array([[2,3,4],[4,5,6]])  ##addition of two array in numpy
y=np.array([[2,3,4],[4,5,6]])
z=x+y
np.array(z)
# Out:
# array([[ 4,  6,  8],
#        [ 8, 10, 12]])

# %%
x=np.array([2,3])  ##dot product 
y=np.array([5,7])
np.dot(x,y)
# Out:
# 31

# %%
a=np.array([0,1,0,1,0])
b=np.array([1,0,1,0,1])
a*b
# Out:
# array([0, 0, 0, 0, 0])

# %%
import pandas as pd    ##getting the current value of bitcoin in usd $$
from pycoingecko import CoinGeckoAPI
cg=CoinGeckoAPI()
bitcoin_data=cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=3)
bitcoin_data
# Out:
# {'prices': [[1641618020444, 41959.08282504925],
#   [1641621744346, 41974.50666226844],
#   [1641625537112, 41952.29226515728],
#   [1641629023990, 41924.13855248408],
#   [1641632770339, 42007.49237135092],
#   [1641636232654, 42187.823029036284],
#   [1641639808637, 41936.80939833606],
#   [1641643321460, 41951.69546447275],
#   [1641647551482, 41939.18949694112],
#   [1641650642323, 41970.268220541315],
#   [1641654209172, 41802.54277533546],
#   [1641657699735, 41723.85138105828],
#   [1641661271282, 41517.616946201764],
#   [1641664878545, 40999.24260500303],
#   [1641668715967, 40655.24908589081],
#   [1641672109968, 40739.225396627015],
#   [1641675697765, 41040.3613698119],
#   [1641679414516, 42240.08706720382],
#   [1641682870751, 42003.66945857541],
#   [1641686602796, 41756.66232397826],
#   [1641690971797, 42000.240211691154],
#   [1641693648250, 41733.04713333396],
#   [1641697257413, 42241.227639919394],
#   [1641701055530, 41927.7407403526],
# ...

# %%
from pycoingecko import CoinGeckoAPI
cg=CoinGeckoAPI()
bitcoin_data=cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=30)
bitcoin_data
# Out:
# {'prices': [[1639126848830, 48193.07284419096],
#   [1639130457550, 48427.92785108339],
#   [1639134113638, 48299.783462010135],
#   [1639137789306, 48787.38348979893],
#   [1639141330018, 49042.23447664938],
#   [1639145062676, 49818.20930772838],
#   [1639148410277, 48502.2965912388],
#   [1639152260099, 47975.15304147276],
#   [1639155849060, 47791.90707503677],
#   [1639159395923, 47654.188646770155],
#   [1639162948736, 47922.84662578528],
#   [1639166624528, 48209.16511108607],
#   [1639170191967, 48319.703000345966],
#   [1639173637168, 48076.73504444962],
#   [1639177279937, 47794.90633433799],
#   [1639180852961, 47303.56415217411],
#   [1639184764800, 47893.22228842599],
#   [1639188005726, 47946.322640924154],
#   [1639191791515, 48279.654639815606],
#   [1639195500237, 48411.20203673279],
#   [1639198961584, 48614.30219146143],
#   [1639202510906, 48449.17391780856],
#   [1639206197912, 48205.027297392626],
#   [1639209695817, 48153.3718089254],
# ...

# %%
import pandas as pd     ##representation of a bitcoin in a candle stick.
import numpy as np
import plotly.graph_objects as go
from plotly.offline import plot
import matplotlib.pyplot as plt
import datetime
from pycoingecko import CoinGeckoAPI
from mplfinance.original_flavor import candlestick2_ohlc
cg = CoinGeckoAPI()
bitcoin_data = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=30)
bitcoin_price_data = bitcoin_data['prices']
bitcoin_price_data[0:5]
data = pd.DataFrame(bitcoin_price_data, columns=['TimeStamp', 'Price'])
data['date'] = data['TimeStamp'].apply(lambda d: datetime.date.fromtimestamp(d/1000.0))
candlestick_data = data.groupby(data.date, as_index=False).agg({"Price": ['min', 'max', 'first', 'last']})
fig = go.Figure(data=[go.Candlestick(x=candlestick_data['date'],
                open=candlestick_data['Price']['first'], 
                high=candlestick_data['Price']['max'],
                low=candlestick_data['Price']['min'], 
                close=candlestick_data['Price']['last'])
                ])

fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <div>                            <div id="883c2e5c-8867-4d3b-9c05-77cd106d4a7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("883c2e5c-8867-4d3b-9c05-77cd106d4a7c")) {                    Plotly.newPlot(                        "883c2e5c-8867-4d3b-9c05-77cd106d4a7c",                        [{"close":[47654.188646770155,48723.11187898166,50281.73854518594,47529.663958106394,46690.6359404706,47219.46906940856,48175.01604749774,46779.28084436036,46731.57588395016,47134.94749909943,46351.75689570818,48747.67695707271,49139.640439658244,50304.24274085634,51244.50702275757,50720.52898789745,50356.053142205725,51956.630209564806,48127.48272515466,47682.67097827655,47759.61113268076,47040.67378897002,48033.24524853784,47407.767815864674,46728.74918128138,46
# ...

# %%
cg = CoinGeckoAPI()  ##bitcoin data in price and data format from pandas lib.
bitcoin_data = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=30)
bitcoin_price_data = bitcoin_data['prices']
bitcoin_price_data[0:5]
data = pd.DataFrame(bitcoin_price_data, columns=['TimeStamp', 'Price'])
data
# Out:
#          TimeStamp         Price
# 0    1639126848830  48193.072844
# 1    1639130457550  48427.927851
# 2    1639134113638  48299.783462
# 3    1639137789306  48787.383490
# 4    1639141330018  49042.234477
# ..             ...           ...
# 717  1641704531951  42161.699862
# 718  1641708343770  41826.917658
# 719  1641712094243  41990.908275
# 720  1641715312369  41915.904932
# 721  1641719651000  41812.766765
#
# [722 rows x 2 columns]

# %%
## Here we are defing the IBM watson Text to Speech:
# !pip install ibm_watson wget
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-5.3.0-py3-none-any.whl size=408872 sha256=03f38557eff59567680cd94be428e2b71a39c6e172c4a3460fdb1552921e7298
#   Stored in directory: c:\users\ayush siloiya\appdata\local\pip\cache\wheels\6c\74\80\01e29d27eb78c279ecab947531c65fb823da9f372de9b46cfa
# ...
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.13.2-py3-none-any.whl size=83241 sha256=7c5ce20ad736a063758d60f1b1c7732f33f1f97a089b9c055d5cbee39d28c3ee
#   Stored in directory: c:\users\ayush siloiya\appdata\local\pip\cache\wheels\46\f7\f2\34e2e9f29faa6f68e1638108fb79b15fc6fd0c9a903bd9ab85
# ...

# %%
from ibm_watson import SpeechToTextV1 
import json
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
url_s2t = "GG-Uphc3iVtaCQGzayGgRPqoQd5IbHyIESdriMZOJM0p"
iam_apikey_s2t = "GG-Uphc3iVtaCQGzayGgRPqoQd5IbHyIESdriMZOJM0p"
authenticator = IAMAuthenticator(iam_apikey_s2t)
s2t = SpeechToTextV1(authenticator=authenticator)
s2t.set_service_url(url_s2t)
s2t

# %%
from ibm_watson import LanguageTranslatorV3
url_lt='https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/0e11734c-8b13-40b2-b584-786521a695be'
apikey_lt='lry6ccuHuqJMNMqbZ-mQ-CuegdApjCk3C-F_DHdzzEDw'
version_lt='2018-05-01'
authenticator = IAMAuthenticator(apikey_lt)
language_translator = LanguageTranslatorV3(version=version_lt,authenticator=authenticator)
language_translator.set_service_url(url_lt)
language_translator

# %%
##status code::
## 100 line indicates that everything is ok so far.
## 20o line indicates that success.
## 300 line indicates that 
## 400 bad news 
## 500 inidcates the server error.
## get retrive a data 
## post send the data.

import requests  ##making a requests in http.
url='http://www.google.com'
r=requests.get(url)
r.status_code
# Out:
# 200

# %%
r.request.headers  ## headers for request source .
# Out:
# {'User-Agent': 'python-requests/2.26.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
r.request.body  ##body content (none)

# %%
header=r.headers  ## date of event.
header['Date']
# Out:
# 'Sun, 09 Jan 2022 09:50:47 GMT'

# %%
r.encoding  ##checking the file encryption.
# Out:
# 'ISO-8859-1'

# %%
header['content-type']  ## type of a content.
# Out:
# 'text/html; charset=ISO-8859-1'

# %%
import requests 
url='https://www.ibm.com/'
r=requests.get(url)
r.status_code
# Out:
# 200

# %%
header=r.headers
header['date']
# Out:
# 'Sun, 09 Jan 2022 11:50:50 GMT'

# %%
r.text[0:100]
# Out:
# '<!DOCTYPE html>\n<html lang="en-in" dir="ltr">\n  <head>\n    <meta charset="utf-8" />\n<script>digitalD'

# %%
##create a query string.
## we are pushing the data into the server.
import requests
url_get='http://httpbin.org/get'  # here we are retrive the data so we use get at the last of url by forward slash.
payload={'Name':'Ayush','Id':123}
r=requests.get(url_get,params=payload)
r.url
# Out:
# 'http://httpbin.org/get?Name=Ayush&Id=123'

# %%
r.text
# Out:
# '{\n  "args": {\n    "Id": "123", \n    "Name": "Ayush"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.26.0", \n    "X-Amzn-Trace-Id": "Root=1-61dace7b-323e1edb72f526554a534145"\n  }, \n  "origin": "45.252.77.106", \n  "url": "http://httpbin.org/get?Name=Ayush&Id=123"\n}\n'

# %%
r.headers
# Out:
# {'Date': 'Sun, 09 Jan 2022 12:00:59 GMT', 'Content-Type': 'application/json', 'Content-Length': '369', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.connection

# %%
r.json()
# Out:
# {'args': {'Id': '123', 'Name': 'Ayush'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.26.0',
#   'X-Amzn-Trace-Id': 'Root=1-61dace7b-323e1edb72f526554a534145'},
#  'origin': '45.252.77.106',
#  'url': 'http://httpbin.org/get?Name=Ayush&Id=123'}

# %%
##  now we will send the data to the server , by using the post at the last.
url_post='http://httpbin.org/post'
payload={'Name':'Ayush','Id':123}
r=requests.post(url_post,params=payload)
r.url
# Out:
# 'http://httpbin.org/post?Name=Ayush&Id=123'

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Sun, 09 Jan 2022 12:09:12 GMT', 'Content-Type': 'application/json', 'Content-Length': '461', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.json()
# Out:
# {'args': {'Id': '123', 'Name': 'Ayush'},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.26.0',
#   'X-Amzn-Trace-Id': 'Root=1-61dad120-68f15a8340a03f2b27abe35d'},
#  'json': None,
#  'origin': '45.252.77.106',
#  'url': 'http://httpbin.org/post?Name=Ayush&Id=123'}

# %%
r.json()['form']
# Out:
# {}

# %%
from bs4 import BeautifulSoup  ## webscraping wiht help of python.
html='<!DOCTYPE html><html><head><title>testing the page</title></head><body><h3><b>Ayush</b></h3><h3><b>Samiksha</b></h3></body></html>'
soup=BeautifulSoup(html,'html5lib')
tag_object=soup.title
tag_object
# Out:
# <title>testing the page</title>

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b>Ayush</b></h3>

# %%
## more objects are .parent , .next_sibling ,.b ,.attrs ,.string .
## table_row[0] , .find_all(name='tr') , .prettify(). 
## web scrapping.
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"
soup=BeautifulSoup(html,'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
tag_child =tag_object.b
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b>Ayush</b></h3>

# %%
 int(12.3)
# Out:
# 12

# %%
'1'+'2'
# Out:
# '12'

# %%
 int(False)
# Out:
# 0

# %%
x=1/1 
x
# Out:
# 1.0

# %%
##split always returns list of words.
x=1
x>-5
# Out:
# True

# %%
len(['disco',10])
# Out:
# 2

# %%
len([1,2,3,4,5])
# Out:
# 5

# %%
import pandas as pd
from pycoingecko import CoinGeckoAPI
cg=CoinGeckoAPI()
bitcoin_price=cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=30)
bitcoin_price
# Out:
# {'prices': [[1639288865855, 48960.85334413465],
#   [1639292459622, 49175.648905315844],
#   [1639296265442, 49372.66649549197],
#   [1639299796778, 49074.457972027565],
#   [1639303348484, 48901.686410926435],
#   [1639306974110, 48912.99820188667],
#   [1639310477792, 49201.37039670038],
#   [1639314082084, 49515.4492319399],
#   [1639317848873, 49715.54895894447],
#   [1639321252677, 49884.22769154073],
#   [1639325028688, 49696.42130099403],
#   [1639328598238, 49874.614648465984],
#   [1639332251359, 50281.73854518594],
#   [1639335697114, 50473.826329249794],
#   [1639339354699, 50257.31197197095],
#   [1639342956085, 50334.77067449245],
#   [1639346555017, 49984.11574879738],
#   [1639350236204, 50194.645523800966],
#   [1639353818296, 50051.078348674855],
#   [1639357204899, 49794.577684297234],
#   [1639361077571, 48923.032102749356],
#   [1639364603927, 48825.743863953336],
#   [1639368163690, 49053.72653067671],
#   [1639371800853, 49126.91802862972],
# ...

# %%
import requests
url_get='http://httpbin.org/get'
payload={'Name':'Ayush','Age':20}
r=requests.get(url_get,params=payload)
r.url
# Out:
# 'http://httpbin.org/get?Name=Ayush&Age=20'

# %%
import requests
url_post='http://httpbin.org/post'
payload={'Name':'Ayush','Age':20}
r=requests.post(url_post,params=payload)
r.url
# Out:
# 'http://httpbin.org/post?Name=Ayush&Age=20'

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Tue, 11 Jan 2022 13:36:49 GMT', 'Content-Type': 'application/json', 'Content-Length': '461', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.json()
# Out:
# {'args': {'Age': '20', 'Name': 'Ayush'},
#  'data': '',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Content-Length': '0',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.26.0',
#   'X-Amzn-Trace-Id': 'Root=1-61dd87f1-283f5b4e192c4a3f71d686af'},
#  'json': None,
#  'origin': '45.252.77.111',
#  'url': 'http://httpbin.org/post?Name=Ayush&Age=20'}

# %%
from bs4 import BeautifulSoup
html='<!DOCTYPE html><html><head><title>testing the page</title></head><body><h3><b>Ayush</b></h3><h3><b>Samiksha</b></h3></body></html>'
soup=BeautifulSoup(html,'html5lib')
tag_object=soup.title
tag_object
# Out:
# <title>testing the page</title>

# %%
tag_object=soup.find_all(name='b')
tag_object
# Out:
# [<b>Ayush</b>, <b>Samiksha</b>]

# %%
import requests
url_post='http://bin.org/post'
payload={'Name':'Ayush','Age':20}
r=requests.post(url_post,params=payload)
r.url
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11002] getaddrinfo failed
#
# ...
